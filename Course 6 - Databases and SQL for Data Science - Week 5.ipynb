# %% [markdown]
# # Problem 1: Find the total number of crimes recorded in the CRIME table

# %% [markdown]
# ![1%20total%20number%20of%20crimes%20from%20crimes%20table.png](attachment:1%20total%20number%20of%20crimes%20from%20crimes%20table.png)

# %% [markdown]
# # Problem 2: List community areas with per capita income less than 11000

# %% [markdown]
# ![2%20per%20capita%20income%20less%20than%2011000.png](attachment:2%20per%20capita%20income%20less%20than%2011000.png)

# %% [markdown]
# # Problem 3: List all case numbers for crimes involving minors?

# %% [markdown]
# ![3%20case%20numbers%20for%20crimes%20involving%20minors.png](attachment:3%20case%20numbers%20for%20crimes%20involving%20minors.png)

# %% [markdown]
# # Problem 4: List all kidnapping crimes involving a child?

# %% [markdown]
# ![4%20all%20kidnapping%20crimes%20involving%20a%20child.png](attachment:4%20all%20kidnapping%20crimes%20involving%20a%20child.png)

# %% [markdown]
# # Problem 5: What kind of crimes were recorded at schools?

# %% [markdown]
# ![5%20crimes%20recorded%20at%20schools.png](attachment:5%20crimes%20recorded%20at%20schools.png)

# %% [markdown]
# # Problem 6: List the average safety score for all types of schools

# %% [markdown]
# ![6%20average%20safety%20scores.png](attachment:6%20average%20safety%20scores.png)

# %% [markdown]
# # Problem 7: List 5 community areas with the highest % of households below poverty line.

# %% [markdown]
# ![7%20household%20poverty.png](attachment:7%20household%20poverty.png)

# %% [markdown]
# # Problem 8: Which community area (number) is most crime prone?

# %% [markdown]
# ![8%20most%20crime%20prone%20area.png](attachment:8%20most%20crime%20prone%20area.png)

# %% [markdown]
# # Problem 9: Use a sub-query to find the name of the community area with highest hardship index.

# %% [markdown]
# ![9%20community%20with%20highest%20hardship%20index.png](attachment:9%20community%20with%20highest%20hardship%20index.png)

# %% [markdown]
# # Problem 10: Use a sub-query to determine the community area name with most number of crimes?

# %% [markdown]
# ![10%20community%20with%20most%20amount%20of%20crime.png](attachment:10%20community%20with%20most%20amount%20of%20crime.png)
